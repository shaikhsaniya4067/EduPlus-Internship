# %%
# 1. Import the NLTK library and check its version installed on your system.
import nltk
print("NLTK Version:", nltk.__version__)
# Out:
# NLTK Version: 3.9.2

# %%
# 2. Download all required NLTK resources (punkt, stopwords, wordnet, averaged_perceptron_tagger_eng) using nltk.download().
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Expert\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Expert\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Expert\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Expert\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
# 3. Write a Python program to tokenize a given paragraph into sentences using sent_tokenize().
from nltk.tokenize import sent_tokenize
text = "Natural Language Processing with NLTK is fun and eduacational. Let's learn it step by step!"
sentences = sent_tokenize(text)
print(f"Sentences:", sentences)
# Out:
# Sentences: ['Natural Language Processing with NLTK is fun and eduacational.', "Let's learn it step by step!"]

# %%
# 4. Tokenize the same paragraph into individual words using word_tokenize()
from nltk.tokenize import word_tokenize
words = word_tokenize(text)
print("\nWords:", words)
# Out:
# Words: ['Natural', 'Language', 'Processing', 'with', 'NLTK', 'is', 'fun', 'and', 'eduacational', '.', 'Let', "'s", 'learn', 'it', 'step', 'by', 'step', '!']

# %%
# 5. Remove stopwords from a given text using NLTK stopwords list.
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [w for w in words if w.lower() not in stop_words]
print("\nAfter Stopword Removal:", filtered_words)
# Out:
# After Stopword Removal: ['Natural', 'Language', 'Processing', 'NLTK', 'fun', 'eduacational', '.', 'Let', "'s", 'learn', 'step', 'step', '!']

# %%
# 6. Perform stemming on a list of words using the PorterStemmer and print the output.
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(w) for w in filtered_words]

print("Stemmed words:\n", stemmed_words)
# Out:
# Stemmed words:
#  ['natur', 'languag', 'process', 'nltk', 'fun', 'eduac', '.', 'let', "'s", 'learn', 'step', 'step', '!']

# %%
# 7. Perform lemmatization on the same list of words using WordNetLemmatizer and compare results with stemming.
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(w) for w in filtered_words]

print("Lemmatized Words:\n", lemmatized_words)
# Out:
# Lemmatized Words:
#  ['Natural', 'Language', 'Processing', 'NLTK', 'fun', 'eduacational', '.', 'Let', "'s", 'learn', 'step', 'step', '!']

# %%
# 8. Apply Part of Speech (POS) tagging to a given sentence and print each word with its tag.
pas_tags = nltk.pos_tag(filtered_words)
print("Part of Speech Tagging:\n", pas_tags)
# Out:
# Part of Speech Tagging:
#  [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('NLTK', 'NNP'), ('fun', 'VBD'), ('eduacational', 'JJ'), ('.', '.'), ('Let', 'VB'), ("'s", 'POS'), ('learn', 'JJ'), ('step', 'NN'), ('step', 'NN'), ('!', '.')]

# %%
# 9. Perform frequency distribution on a paragraph and print the top 10 most frequent words.
from nltk import FreqDist
fdist = FreqDist(filtered_words)
print("\nTop 10 Frequent Words:", fdist.most_common(10))
# Out:
# Top 10 Frequent Words: [('step', 2), ('Natural', 1), ('Language', 1), ('Processing', 1), ('NLTK', 1), ('fun', 1), ('eduacational', 1), ('.', 1), ('Let', 1), ("'s", 1)]

# %%
# 10. Plot a graph of the top 15 most frequent words using FreqDist().plot().
fdist.plot(15, title="Top 15 Word Frequencies")
# Out:
# <Axes: title={'center': 'Top 15 Word Frequencies'}, xlabel='Samples', ylabel='Counts'>
